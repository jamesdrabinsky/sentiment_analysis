# %%
import pandas as pd
import json

# %%
with open('./-f', 'r') as f:
    data = []
    for line in f.readlines():
        data.append(json.loads(line))

# %%
# This loads the most comprehensive text portion of the tweet  
# Where "tweet" is an individual tweet, treated as JSON / dict
def getText(tweet):       
# Try for extended text of original tweet, if RT'd (streamer)
    try:
        text = tweet['retweeted_status']['extended_tweet']['full_text']
    except: 
    # Try for extended text of an original tweet, if RT'd (REST API)
        try: 
            text = tweet['retweeted_status']['full_text']
        except:
        # Try for extended text of an original tweet (streamer)
            try: 
                text = tweet['extended_tweet']['full_text']
            except:
            # Try for extended text of an original tweet (REST API)
                try: 
                    text = tweet['full_text']
                except:
                # Try for basic text of original tweet if RT'd 
                    try: 
                        text = tweet['retweeted_status']['text']
                    except:
                    # Try for basic text of an original tweet
                        try: 
                            text = tweet['text']
                        except: 
                        # Nothing left to check for
                            text = ''
    return text

# %%
all_info = pd.DataFrame(data)

# %%
tweet_lst = []

for i,item in enumerate(data):
    full_text = {'full_text':getText(item)}
    tweet_lst.append(full_text)

# %%
all_info['full_text'] = pd.DataFrame(tweet_lst)
all_info.head()
# Out:
#   contributors coordinates                      created_at display_text_range  \
# 0         None        None  Wed Oct 10 23:48:24 +0000 2018                NaN
# 1         None        None  Wed Oct 10 23:48:25 +0000 2018            [0, 23]
# 2         None        None  Wed Oct 10 23:48:26 +0000 2018                NaN
# 3         None        None  Wed Oct 10 23:48:35 +0000 2018                NaN
# 4         None        None  Wed Oct 10 23:48:38 +0000 2018                NaN
#
#                                             entities  \
# 0  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                    extended_entities extended_tweet  \
# 0                                                NaN            NaN
# ...

# %%
all_info.to_csv('./Data/tweets_September30.csv')

# %%
len(tweet_lst)
# Out:
# 292
